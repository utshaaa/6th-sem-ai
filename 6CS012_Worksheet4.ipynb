# %% [markdown]
# #Installing Keras.

# %%
pip install keras tensorflow
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (3.13.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras) (3.16.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras) (0.19.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras) (26.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)

# %% [markdown]
# #Identifying the version of Keras.

# %%
import tensorflow as tf
print(tf.keras.__version__)
# Out:
# 3.13.2

# %% [markdown]
# #Manual Gradient Calculation in Numpy

# %%
import numpy as np
# Simple function f(x) = x^2
def f(x):
  return x ** 2
# Manual derivative (f'(x) = 2x)
def gradient(x):
  return 2 * x
# Update rule: x = x - learning_rate * gradient
x = 5.0
learning_rate = 0.1
for _ in range(10): # Manually optimize for 10 steps
  x -= learning_rate * gradient(x)
print(f"x: {x}, f(x): {f(x)}")
# Out:
# x: 0.5368709120000001, f(x): 0.2882303761517119

# %% [markdown]
# #Gradient Computations with Keras.

# %%
import tensorflow as tf
x = tf.Variable(5.0) # Trainable variable
with tf.GradientTape() as tape:
  y = x ** 2 # y = x^2
grad = tape.gradient(y, x) # Computes dy/dx automatically
print(grad.numpy()) # Output: 10.0
# Out:
# 10.0

# %% [markdown]
# #Matrix Multiplication Speed (Numpy vs. Tensorflow on GPU).

# %%
import numpy as np
import tensorflow as tf
import time
# Create large random matrices
size = (1000, 1000)
A = np.random.rand(*size)
B = np.random.rand(*size)
# NumPy Multiplication
start = time.time()
C_numpy = np.dot(A, B)
print("NumPy Time:", time.time() - start)
# TensorFlow Multiplication (for colab uses GPU Runtime if available)
A_tf = tf.constant(A)
B_tf = tf.constant(B)
start = time.time()
C_tf = tf.matmul(A_tf, B_tf)
print("TensorFlow Time:", time.time() - start)
# Out:
# NumPy Time: 0.3267984390258789
# TensorFlow Time: 0.3315315246582031

# %% [markdown]
# #Implementation of Activation Function with Keras.

# %%
from tensorflow.keras.layers import Dense
layer = Dense(64, activation='sigmoid')

# %% [markdown]
# #Manually Training Network in Numpy.

# %%
import numpy as np

# Initialize random data for x_train, y_train
x_train = np.random.rand(100, 1) # 100 samples, 1 feature
y_train = 2 * x_train + 1 + np.random.randn(100, 1) * 0.1 # y = 2x + 1 + noise

# Initialize weights randomly
weights = np.random.rand(1, 1)

# Learning rate is already defined from a previous cell, but re-defining for completeness
learning_rate = 0.1

for epoch in range(10):
# Forward pass
  y_pred = np.dot(x_train, weights)
# Compute loss
  loss = np.mean((y_pred - y_train) ** 2)
# Compute gradients manually
  gradients = 2 * np.dot(x_train.T, (y_pred - y_train)) / len(x_train)
# Update weights
  weights -= learning_rate * gradients

print(f"Final weights: {weights}")
print(f"Final loss: {loss}")
# Out:
# Final weights: [[1.67882701]]
# Final loss: 1.4463243292463037

# %% [markdown]
# #Keras training in One line

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

# Define a simple Sequential model
model = models.Sequential([
    layers.Dense(1, input_shape=(1,))
])

# Compile the model
model.compile(optimizer='sgd', loss='mse')

# Now, fit the model
model.fit(x_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2216
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3260
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5677
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9959
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5156
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1055
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7917
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5198
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2634
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0728

# %% [markdown]
# #Layers in Keras.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential([
Dense(64, activation='relu', input_shape=(784,)),
Dense(10, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #Implementing SGD in Numpy.

# %%
learning_rate = 0.01
weights = np.random.randn(3, 3)
for _ in range(100): # Training loop
  gradient = np.random.randn(3, 3) # Fake gradient for illustration
  weights -= learning_rate * gradient

# %% [markdown]
# #In Keras.

# %%
from tensorflow.keras.optimizers import SGD
optimizer = SGD(learning_rate=0.01)

# %% [markdown]
# #Suntax of Dense Layer.

# %%
from tensorflow.keras.layers import Dense
layer = Dense(32, activation=None, use_bias=True, kernel_initializer="glorot_uniform")

# %% [markdown]
# #A Dense Layer with 64 Neurons and sigmoid Activation.

# %%
from tensorflow.keras.layers import Dense
layer = Dense(64, activation="sigmoid") # 64 neurons with sigmoid activation

# %% [markdown]
# #Loading and Preprocessing Data with PIL.

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from PIL import Image # Import Pillow
# Define dataset paths
train_dir = "/content/DevanagariHandwrittenDigitDataset/Train/"
test_dir = "/content/DevanagariHandwrittenDigitDataset/Test/"
# Define image size
img_height, img_width = 28, 28
# Function to load images and labels using PIL
def load_images_from_folder(folder):
  images = []
  labels = []
  class_names = sorted(os.listdir(folder)) # Sorted class names (digit_0, digit_1, ...)
  class_map = {name: i for i, name in enumerate(class_names)} # Map class names to labels
  for class_name in class_names:
    class_path = os.path.join(folder, class_name)
    label = class_map[class_name]
    for filename in os.listdir(class_path):
      img_path = os.path.join(class_path, filename)
# Load image using PIL
      img = Image.open(img_path).convert("L") # Convert to grayscale
      img = img.resize((img_width, img_height)) # Resize to (28,28)
      img = np.array(img) / 255.0 # Normalize pixel values to [0,1]
      images.append(img)
      labels.append(label)
  return np.array(images), np.array(labels)
# Load training and testing datasets
x_train, y_train = load_images_from_folder(train_dir)
x_test, y_test = load_images_from_folder(test_dir)
# Reshape images for Keras input
x_train = x_train.reshape(-1, img_height, img_width, 1) # Shape (num_samples, 28, 28, 1)
x_test = x_test.reshape(-1, img_height, img_width, 1)
# One-hot encode labels
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)
# Print dataset shape
print(f"Training set: {x_train.shape}, Labels: {y_train.shape}")
print(f"Testing set: {x_test.shape}, Labels: {y_test.shape}")
# Visualize some images
plt.figure(figsize=(10, 4))
for i in range(10):
  plt.subplot(2, 5, i + 1)
  plt.imshow(x_train[i].reshape(28, 28), cmap='gray')
  plt.title(f"Label: {np.argmax(y_train[i])}")
  plt.axis("off")
plt.show()
# Out:
# Training set: (17000, 28, 28, 1), Labels: (17000, 10)
# Testing set: (3000, 28, 28, 1), Labels: (3000, 10)

# %%
# !unzip "/content/Copy of devnagari digit.zip"
# Out:
# Archive:  /content/Copy of devnagari digit.zip
# replace DevanagariHandwrittenDigitDataset/Test/digit_0/103277.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# #Compatibility check for Grayscale Image:

# %%
x_train = x_train.reshape(-1, img_height, img_width, 1)

# %% [markdown]
# #Loading and Preprocessing MNIST Handwritten Digit Dataset:

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Normalize the images to values between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0
# Reshape the 28x28 images to (28, 28, 1) for the model input
x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)
# One-hot encode the labels (0-9) for classification
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# %% [markdown]
# #Example using Sequential API.

# %%
# Model parameters
import tensorflow as tf
from tensorflow import keras
num_classes = 10
input_shape = (28, 28, 1)
model = keras.Sequential(
[
keras.layers.Input(shape=input_shape),
keras.layers.Flatten(), # Flatten the 28x28 image to a 784-dimensional vector
keras.layers.Dense(64, activation="sigmoid"),
keras.layers.Dense(128, activation="sigmoid"),
keras.layers.Dense(256, activation="sigmoid"),
keras.layers.Dense(num_classes, activation="softmax"),
]
)

# %% [markdown]
# #Syntax Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Example using Functional API.

# %%
# Model parameters
import tensorflow as tf
from tensorflow import keras
num_classes = 10
input_shape = (28, 28, 1)
def build_functional_model():
# Input layer
  inputs = keras.Input(shape=input_shape)
# Flatten layer
  x = keras.layers.Flatten()(inputs)
# Hidden layers
  x = keras.layers.Dense(64, activation="sigmoid")(x)
  x = keras.layers.Dense(128, activation="sigmoid")(x)
  x = keras.layers.Dense(256, activation="sigmoid")(x)
# Output layer
  outputs = keras.layers.Dense(num_classes, activation="softmax")(x)
# Create model
  model = keras.Model(inputs=inputs, outputs=outputs)
  return model
# Build the model
functional_model = build_functional_model()
functional_model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 94,154 (367.79 KB)
#  Trainable params: 94,154 (367.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #Syntax of model.compile():

# %%
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy']
)

# %% [markdown]
# #Example: Compiling the Model

# %%
model.build(input_shape=(None,) + input_shape)
model.compile(
optimizer="sgd", # Stochastic Gradient Descent
loss="categorical_crossentropy", # Loss function for multi-class classification
metrics=["accuracy"] # Track accuracy during training
)

# %% [markdown]
# #Syntax of fit() function.

# %%
model.fit(
  x=x_train,
  y=y_train,
  batch_size=32,
  epochs=10,
  validation_data=(x_test, y_test),
  verbose=2
)
# Out:
# Epoch 1/10
# 1875/1875 - 8s - 4ms/step - accuracy: 0.1114 - loss: 2.3036 - val_accuracy: 0.1895 - val_loss: 2.3004
# Epoch 2/10
# 1875/1875 - 9s - 5ms/step - accuracy: 0.1303 - loss: 2.2929 - val_accuracy: 0.1164 - val_loss: 2.2844
# Epoch 3/10
# 1875/1875 - 7s - 4ms/step - accuracy: 0.1677 - loss: 2.2741 - val_accuracy: 0.3099 - val_loss: 2.2554
# Epoch 4/10
# 1875/1875 - 5s - 3ms/step - accuracy: 0.2754 - loss: 2.2187 - val_accuracy: 0.3450 - val_loss: 2.1493
# Epoch 5/10
# 1875/1875 - 6s - 3ms/step - accuracy: 0.3696 - loss: 1.9933 - val_accuracy: 0.3842 - val_loss: 1.7616
# Epoch 6/10
# 1875/1875 - 8s - 4ms/step - accuracy: 0.4674 - loss: 1.5646 - val_accuracy: 0.5308 - val_loss: 1.3916
# Epoch 7/10
# 1875/1875 - 10s - 6ms/step - accuracy: 0.5877 - loss: 1.2797 - val_accuracy: 0.6584 - val_loss: 1.1489
# Epoch 8/10
# 1875/1875 - 8s - 4ms/step - accuracy: 0.6867 - loss: 1.0379 - val_accuracy: 0.7138 - val_loss: 0.9172
# Epoch 9/10
# 1875/1875 - 5s - 3ms/step - accuracy: 0.7447 - loss: 0.8507 - val_accuracy: 0.7751 - val_loss: 0.7720
# Epoch 10/10
# 1875/1875 - 8s - 4ms/step - accuracy: 0.7806 - loss: 0.7366 - val_accuracy: 0.8060 - val_loss: 0.6757

# %% [markdown]
# #Example Code for fit()

# %%
batch_size = 128
epochs = 2000
# Callbacks
callbacks = [
keras.callbacks.ModelCheckpoint(filepath="model_at_epoch_{epoch}.keras"),
keras.callbacks.EarlyStopping(monitor="val_loss", patience=4 ),
]
# Train the model with callbacks and validation split
history = model.fit(
x_train,
y_train,
batch_size=batch_size,
epochs=epochs,
validation_split=0.15,
callbacks=callbacks,
)
# Out:
# Epoch 1/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7982 - loss: 0.6894 - val_accuracy: 0.8282 - val_loss: 0.6233
# Epoch 2/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8047 - loss: 0.6724 - val_accuracy: 0.8376 - val_loss: 0.6076
# Epoch 3/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8112 - loss: 0.6558 - val_accuracy: 0.8398 - val_loss: 0.5924
# Epoch 4/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8164 - loss: 0.6401 - val_accuracy: 0.8423 - val_loss: 0.5774
# Epoch 5/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8220 - loss: 0.6249 - val_accuracy: 0.8461 - val_loss: 0.5635
# Epoch 6/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8267 - loss: 0.6103 - val_accuracy: 0.8503 - val_loss: 0.5494
# Epoch 7/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8315 - loss: 0.5966 - val_accuracy: 0.8556 - val_loss: 0.5369
# Epoch 8/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8357 - loss: 0.5836 - val_accuracy: 0.8559 - val_loss: 0.5259
# Epoch 9/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8388 - loss: 0.5714 - val_accuracy: 0.8593 - val_loss: 0.5139
# Epoch 10/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8431 - loss: 0.5596 - val_accuracy: 0.8619 - val_loss: 0.5040
# Epoch 11/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8466 - loss: 0.5488 - val_accuracy: 0.8653 - val_loss: 0.4937
# Epoch 12/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8495 - loss: 0.5386 - val_accuracy: 0.8672 - val_loss: 0.4845
# Epoch 13/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8523 - loss: 0.5291 - val_accuracy: 0.8691 - val_loss: 0.4763
# Epoch 14/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8549 - loss: 0.5201 - val_accuracy: 0.8694 - val_loss: 0.4695
# Epoch 15/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8563 - loss: 0.5118 - val_accuracy: 0.8723 - val_loss: 0.4614
# Epoch 16/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8584 - loss: 0.5038 - val_accuracy: 0.8746 - val_loss: 0.4545
# Epoch 17/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8610 - loss: 0.4964 - val_accuracy: 0.8764 - val_loss: 0.4475
# Epoch 18/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8622 - loss: 0.4895 - val_accuracy: 0.8776 - val_loss: 0.4413
# Epoch 19/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8641 - loss: 0.4828 - val_accuracy: 0.8794 - val_loss: 0.4356
# Epoch 20/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8661 - loss: 0.4766 - val_accuracy: 0.8803 - val_loss: 0.4297
# Epoch 21/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8674 - loss: 0.4706 - val_accuracy: 0.8803 - val_loss: 0.4250
# Epoch 22/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8693 - loss: 0.4650 - val_accuracy: 0.8816 - val_loss: 0.4192
# Epoch 23/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8708 - loss: 0.4596 - val_accuracy: 0.8832 - val_loss: 0.4143
# Epoch 24/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8719 - loss: 0.4545 - val_accuracy: 0.8837 - val_loss: 0.4099
# Epoch 25/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8736 - loss: 0.4494 - val_accuracy: 0.8860 - val_loss: 0.4053
# Epoch 26/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8747 - loss: 0.4446 - val_accuracy: 0.8870 - val_loss: 0.4014
# Epoch 27/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8761 - loss: 0.4402 - val_accuracy: 0.8879 - val_loss: 0.3971
# Epoch 28/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8772 - loss: 0.4356 - val_accuracy: 0.8886 - val_loss: 0.3936
# Epoch 29/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8784 - loss: 0.4315 - val_accuracy: 0.8883 - val_loss: 0.3900
# Epoch 30/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8798 - loss: 0.4272 - val_accuracy: 0.8899 - val_loss: 0.3856
# Epoch 31/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8808 - loss: 0.4233 - val_accuracy: 0.8907 - val_loss: 0.3816
# Epoch 32/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8818 - loss: 0.4192 - val_accuracy: 0.8926 - val_loss: 0.3791
# Epoch 33/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8829 - loss: 0.4156 - val_accuracy: 0.8922 - val_loss: 0.3754
# Epoch 34/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8838 - loss: 0.4118 - val_accuracy: 0.8934 - val_loss: 0.3714
# Epoch 35/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8845 - loss: 0.4082 - val_accuracy: 0.8950 - val_loss: 0.3690
# Epoch 36/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8854 - loss: 0.4045 - val_accuracy: 0.8948 - val_loss: 0.3657
# Epoch 37/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8856 - loss: 0.4012 - val_accuracy: 0.8966 - val_loss: 0.3622
# Epoch 38/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8870 - loss: 0.3977 - val_accuracy: 0.8977 - val_loss: 0.3595
# Epoch 39/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8887 - loss: 0.3945 - val_accuracy: 0.8979 - val_loss: 0.3564
# Epoch 40/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8894 - loss: 0.3911 - val_accuracy: 0.8993 - val_loss: 0.3535
# Epoch 41/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8897 - loss: 0.3880 - val_accuracy: 0.9004 - val_loss: 0.3501
# Epoch 42/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8908 - loss: 0.3849 - val_accuracy: 0.9006 - val_loss: 0.3480
# Epoch 43/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8920 - loss: 0.3818 - val_accuracy: 0.9013 - val_loss: 0.3446
# Epoch 44/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8927 - loss: 0.3788 - val_accuracy: 0.9030 - val_loss: 0.3424
# Epoch 45/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8940 - loss: 0.3758 - val_accuracy: 0.9042 - val_loss: 0.3397
# Epoch 46/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8948 - loss: 0.3728 - val_accuracy: 0.9036 - val_loss: 0.3376
# Epoch 47/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8955 - loss: 0.3699 - val_accuracy: 0.9046 - val_loss: 0.3344
# Epoch 48/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8964 - loss: 0.3671 - val_accuracy: 0.9044 - val_loss: 0.3329
# Epoch 49/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8971 - loss: 0.3644 - val_accuracy: 0.9061 - val_loss: 0.3301
# Epoch 50/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8979 - loss: 0.3616 - val_accuracy: 0.9051 - val_loss: 0.3280
# Epoch 51/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8988 - loss: 0.3587 - val_accuracy: 0.9072 - val_loss: 0.3246
# Epoch 52/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9002 - loss: 0.3562 - val_accuracy: 0.9070 - val_loss: 0.3227
# Epoch 53/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9001 - loss: 0.3536 - val_accuracy: 0.9081 - val_loss: 0.3203
# Epoch 54/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9009 - loss: 0.3509 - val_accuracy: 0.9088 - val_loss: 0.3182
# Epoch 55/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9019 - loss: 0.3484 - val_accuracy: 0.9083 - val_loss: 0.3165
# Epoch 56/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9022 - loss: 0.3458 - val_accuracy: 0.9102 - val_loss: 0.3139
# Epoch 57/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9032 - loss: 0.3434 - val_accuracy: 0.9090 - val_loss: 0.3121
# Epoch 58/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9036 - loss: 0.3410 - val_accuracy: 0.9110 - val_loss: 0.3095
# Epoch 59/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9049 - loss: 0.3385 - val_accuracy: 0.9117 - val_loss: 0.3072
# Epoch 60/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9054 - loss: 0.3360 - val_accuracy: 0.9127 - val_loss: 0.3052
# Epoch 61/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9063 - loss: 0.3337 - val_accuracy: 0.9137 - val_loss: 0.3029
# Epoch 62/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9062 - loss: 0.3314 - val_accuracy: 0.9143 - val_loss: 0.3006
# Epoch 63/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9072 - loss: 0.3290 - val_accuracy: 0.9149 - val_loss: 0.2995
# Epoch 64/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9080 - loss: 0.3268 - val_accuracy: 0.9152 - val_loss: 0.2970
# Epoch 65/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9088 - loss: 0.3244 - val_accuracy: 0.9151 - val_loss: 0.2946
# Epoch 66/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9092 - loss: 0.3222 - val_accuracy: 0.9163 - val_loss: 0.2925
# Epoch 67/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9098 - loss: 0.3200 - val_accuracy: 0.9166 - val_loss: 0.2912
# Epoch 68/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9104 - loss: 0.3178 - val_accuracy: 0.9178 - val_loss: 0.2889
# Epoch 69/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9112 - loss: 0.3156 - val_accuracy: 0.9182 - val_loss: 0.2866
# Epoch 70/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9115 - loss: 0.3135 - val_accuracy: 0.9183 - val_loss: 0.2848
# Epoch 71/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9122 - loss: 0.3112 - val_accuracy: 0.9191 - val_loss: 0.2829
# Epoch 72/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9129 - loss: 0.3091 - val_accuracy: 0.9198 - val_loss: 0.2813
# Epoch 73/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9135 - loss: 0.3071 - val_accuracy: 0.9191 - val_loss: 0.2795
# Epoch 74/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9142 - loss: 0.3050 - val_accuracy: 0.9210 - val_loss: 0.2777
# Epoch 75/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9151 - loss: 0.3029 - val_accuracy: 0.9202 - val_loss: 0.2758
# Epoch 76/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9154 - loss: 0.3009 - val_accuracy: 0.9209 - val_loss: 0.2739
# Epoch 77/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9161 - loss: 0.2989 - val_accuracy: 0.9222 - val_loss: 0.2722
# Epoch 78/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9171 - loss: 0.2968 - val_accuracy: 0.9218 - val_loss: 0.2705
# Epoch 79/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9174 - loss: 0.2949 - val_accuracy: 0.9226 - val_loss: 0.2689
# Epoch 80/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9176 - loss: 0.2930 - val_accuracy: 0.9237 - val_loss: 0.2671
# Epoch 81/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9184 - loss: 0.2911 - val_accuracy: 0.9240 - val_loss: 0.2654
# Epoch 82/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9188 - loss: 0.2892 - val_accuracy: 0.9239 - val_loss: 0.2643
# Epoch 83/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9196 - loss: 0.2873 - val_accuracy: 0.9239 - val_loss: 0.2624
# Epoch 84/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9199 - loss: 0.2854 - val_accuracy: 0.9258 - val_loss: 0.2605
# Epoch 85/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9205 - loss: 0.2834 - val_accuracy: 0.9251 - val_loss: 0.2587
# Epoch 86/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9213 - loss: 0.2817 - val_accuracy: 0.9263 - val_loss: 0.2576
# Epoch 87/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9220 - loss: 0.2799 - val_accuracy: 0.9268 - val_loss: 0.2559
# Epoch 88/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9222 - loss: 0.2781 - val_accuracy: 0.9272 - val_loss: 0.2537
# Epoch 89/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9228 - loss: 0.2763 - val_accuracy: 0.9272 - val_loss: 0.2522
# Epoch 90/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9232 - loss: 0.2746 - val_accuracy: 0.9278 - val_loss: 0.2508
# Epoch 91/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9235 - loss: 0.2729 - val_accuracy: 0.9293 - val_loss: 0.2494
# Epoch 92/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9241 - loss: 0.2712 - val_accuracy: 0.9301 - val_loss: 0.2478
# Epoch 93/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9246 - loss: 0.2695 - val_accuracy: 0.9300 - val_loss: 0.2463
# Epoch 94/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9250 - loss: 0.2677 - val_accuracy: 0.9303 - val_loss: 0.2446
# Epoch 95/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9257 - loss: 0.2662 - val_accuracy: 0.9301 - val_loss: 0.2440
# Epoch 96/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9260 - loss: 0.2645 - val_accuracy: 0.9307 - val_loss: 0.2420
# Epoch 97/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9265 - loss: 0.2629 - val_accuracy: 0.9317 - val_loss: 0.2406
# Epoch 98/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9269 - loss: 0.2614 - val_accuracy: 0.9324 - val_loss: 0.2393
# Epoch 99/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9273 - loss: 0.2597 - val_accuracy: 0.9318 - val_loss: 0.2377
# Epoch 100/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9276 - loss: 0.2581 - val_accuracy: 0.9324 - val_loss: 0.2362
# Epoch 101/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9280 - loss: 0.2565 - val_accuracy: 0.9322 - val_loss: 0.2353
# Epoch 102/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9284 - loss: 0.2551 - val_accuracy: 0.9331 - val_loss: 0.2337
# Epoch 103/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9290 - loss: 0.2535 - val_accuracy: 0.9338 - val_loss: 0.2321
# Epoch 104/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9295 - loss: 0.2518 - val_accuracy: 0.9339 - val_loss: 0.2319
# Epoch 105/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9298 - loss: 0.2505 - val_accuracy: 0.9344 - val_loss: 0.2301
# Epoch 106/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9300 - loss: 0.2490 - val_accuracy: 0.9358 - val_loss: 0.2283
# Epoch 107/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9308 - loss: 0.2476 - val_accuracy: 0.9357 - val_loss: 0.2268
# Epoch 108/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9304 - loss: 0.2462 - val_accuracy: 0.9353 - val_loss: 0.2265
# Epoch 109/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9310 - loss: 0.2448 - val_accuracy: 0.9354 - val_loss: 0.2247
# Epoch 110/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9319 - loss: 0.2433 - val_accuracy: 0.9357 - val_loss: 0.2237
# Epoch 111/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9320 - loss: 0.2419 - val_accuracy: 0.9364 - val_loss: 0.2219
# Epoch 112/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9323 - loss: 0.2405 - val_accuracy: 0.9369 - val_loss: 0.2216
# Epoch 113/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9326 - loss: 0.2392 - val_accuracy: 0.9372 - val_loss: 0.2198
# Epoch 114/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9331 - loss: 0.2379 - val_accuracy: 0.9369 - val_loss: 0.2185
# Epoch 115/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9336 - loss: 0.2365 - val_accuracy: 0.9380 - val_loss: 0.2174
# Epoch 116/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9338 - loss: 0.2351 - val_accuracy: 0.9374 - val_loss: 0.2164
# Epoch 117/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9343 - loss: 0.2339 - val_accuracy: 0.9388 - val_loss: 0.2151
# Epoch 118/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9346 - loss: 0.2325 - val_accuracy: 0.9390 - val_loss: 0.2143
# Epoch 119/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9349 - loss: 0.2313 - val_accuracy: 0.9391 - val_loss: 0.2128
# Epoch 120/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9353 - loss: 0.2300 - val_accuracy: 0.9388 - val_loss: 0.2117
# Epoch 121/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9356 - loss: 0.2287 - val_accuracy: 0.9401 - val_loss: 0.2111
# Epoch 122/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9356 - loss: 0.2275 - val_accuracy: 0.9398 - val_loss: 0.2104
# Epoch 123/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9363 - loss: 0.2263 - val_accuracy: 0.9404 - val_loss: 0.2087
# Epoch 124/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9363 - loss: 0.2250 - val_accuracy: 0.9401 - val_loss: 0.2082
# Epoch 125/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9368 - loss: 0.2239 - val_accuracy: 0.9408 - val_loss: 0.2065
# Epoch 126/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9371 - loss: 0.2226 - val_accuracy: 0.9418 - val_loss: 0.2057
# Epoch 127/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9374 - loss: 0.2214 - val_accuracy: 0.9424 - val_loss: 0.2045
# Epoch 128/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9378 - loss: 0.2202 - val_accuracy: 0.9421 - val_loss: 0.2037
# Epoch 129/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9379 - loss: 0.2191 - val_accuracy: 0.9424 - val_loss: 0.2026
# Epoch 130/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9385 - loss: 0.2179 - val_accuracy: 0.9428 - val_loss: 0.2016
# Epoch 131/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9385 - loss: 0.2168 - val_accuracy: 0.9430 - val_loss: 0.2008
# Epoch 132/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9389 - loss: 0.2157 - val_accuracy: 0.9434 - val_loss: 0.1998
# Epoch 133/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9394 - loss: 0.2145 - val_accuracy: 0.9436 - val_loss: 0.1987
# Epoch 134/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9396 - loss: 0.2134 - val_accuracy: 0.9431 - val_loss: 0.1977
# Epoch 135/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9403 - loss: 0.2123 - val_accuracy: 0.9439 - val_loss: 0.1971
# Epoch 136/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9403 - loss: 0.2112 - val_accuracy: 0.9439 - val_loss: 0.1960
# Epoch 137/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9405 - loss: 0.2101 - val_accuracy: 0.9449 - val_loss: 0.1948
# Epoch 138/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9408 - loss: 0.2091 - val_accuracy: 0.9448 - val_loss: 0.1943
# Epoch 139/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9411 - loss: 0.2081 - val_accuracy: 0.9453 - val_loss: 0.1931
# Epoch 140/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9414 - loss: 0.2070 - val_accuracy: 0.9449 - val_loss: 0.1922
# Epoch 141/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9418 - loss: 0.2059 - val_accuracy: 0.9448 - val_loss: 0.1918
# Epoch 142/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9421 - loss: 0.2049 - val_accuracy: 0.9458 - val_loss: 0.1911
# Epoch 143/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9419 - loss: 0.2038 - val_accuracy: 0.9462 - val_loss: 0.1902
# Epoch 144/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9430 - loss: 0.2028 - val_accuracy: 0.9461 - val_loss: 0.1892
# Epoch 145/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9432 - loss: 0.2019 - val_accuracy: 0.9471 - val_loss: 0.1883
# Epoch 146/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9433 - loss: 0.2009 - val_accuracy: 0.9460 - val_loss: 0.1881
# Epoch 147/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9434 - loss: 0.1999 - val_accuracy: 0.9466 - val_loss: 0.1869
# Epoch 148/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9437 - loss: 0.1989 - val_accuracy: 0.9474 - val_loss: 0.1859
# Epoch 149/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9440 - loss: 0.1979 - val_accuracy: 0.9477 - val_loss: 0.1850
# Epoch 150/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9445 - loss: 0.1970 - val_accuracy: 0.9480 - val_loss: 0.1841
# Epoch 151/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9448 - loss: 0.1960 - val_accuracy: 0.9474 - val_loss: 0.1836
# Epoch 152/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9453 - loss: 0.1951 - val_accuracy: 0.9481 - val_loss: 0.1828
# Epoch 153/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9449 - loss: 0.1941 - val_accuracy: 0.9480 - val_loss: 0.1821
# Epoch 154/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9452 - loss: 0.1931 - val_accuracy: 0.9479 - val_loss: 0.1818
# Epoch 155/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9458 - loss: 0.1922 - val_accuracy: 0.9486 - val_loss: 0.1809
# Epoch 156/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9457 - loss: 0.1914 - val_accuracy: 0.9492 - val_loss: 0.1805
# Epoch 157/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9460 - loss: 0.1904 - val_accuracy: 0.9490 - val_loss: 0.1792
# Epoch 158/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9463 - loss: 0.1896 - val_accuracy: 0.9490 - val_loss: 0.1782
# Epoch 159/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9467 - loss: 0.1886 - val_accuracy: 0.9492 - val_loss: 0.1778
# Epoch 160/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9467 - loss: 0.1877 - val_accuracy: 0.9491 - val_loss: 0.1773
# Epoch 161/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9472 - loss: 0.1869 - val_accuracy: 0.9491 - val_loss: 0.1764
# Epoch 162/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9473 - loss: 0.1860 - val_accuracy: 0.9493 - val_loss: 0.1757
# Epoch 163/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9474 - loss: 0.1852 - val_accuracy: 0.9492 - val_loss: 0.1754
# Epoch 164/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9479 - loss: 0.1843 - val_accuracy: 0.9496 - val_loss: 0.1740
# Epoch 165/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9481 - loss: 0.1834 - val_accuracy: 0.9500 - val_loss: 0.1737
# Epoch 166/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9483 - loss: 0.1826 - val_accuracy: 0.9504 - val_loss: 0.1730
# Epoch 167/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9487 - loss: 0.1817 - val_accuracy: 0.9501 - val_loss: 0.1725
# Epoch 168/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9488 - loss: 0.1809 - val_accuracy: 0.9503 - val_loss: 0.1716
# Epoch 169/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9489 - loss: 0.1800 - val_accuracy: 0.9512 - val_loss: 0.1714
# Epoch 170/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9491 - loss: 0.1793 - val_accuracy: 0.9514 - val_loss: 0.1702
# Epoch 171/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9495 - loss: 0.1784 - val_accuracy: 0.9516 - val_loss: 0.1698
# Epoch 172/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9497 - loss: 0.1776 - val_accuracy: 0.9519 - val_loss: 0.1691
# Epoch 173/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9500 - loss: 0.1768 - val_accuracy: 0.9524 - val_loss: 0.1682
# Epoch 174/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9503 - loss: 0.1760 - val_accuracy: 0.9513 - val_loss: 0.1679
# Epoch 175/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9502 - loss: 0.1752 - val_accuracy: 0.9524 - val_loss: 0.1673
# Epoch 176/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9506 - loss: 0.1745 - val_accuracy: 0.9527 - val_loss: 0.1666
# Epoch 177/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9507 - loss: 0.1737 - val_accuracy: 0.9522 - val_loss: 0.1663
# Epoch 178/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9512 - loss: 0.1729 - val_accuracy: 0.9529 - val_loss: 0.1653
# Epoch 179/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9513 - loss: 0.1722 - val_accuracy: 0.9537 - val_loss: 0.1651
# Epoch 180/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9518 - loss: 0.1714 - val_accuracy: 0.9539 - val_loss: 0.1642
# Epoch 181/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9520 - loss: 0.1707 - val_accuracy: 0.9540 - val_loss: 0.1635
# Epoch 182/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9518 - loss: 0.1699 - val_accuracy: 0.9531 - val_loss: 0.1631
# Epoch 183/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9521 - loss: 0.1691 - val_accuracy: 0.9529 - val_loss: 0.1624
# Epoch 184/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9527 - loss: 0.1684 - val_accuracy: 0.9536 - val_loss: 0.1627
# Epoch 185/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9528 - loss: 0.1677 - val_accuracy: 0.9538 - val_loss: 0.1617
# Epoch 186/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9526 - loss: 0.1669 - val_accuracy: 0.9544 - val_loss: 0.1608
# Epoch 187/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9530 - loss: 0.1662 - val_accuracy: 0.9540 - val_loss: 0.1610
# Epoch 188/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9529 - loss: 0.1655 - val_accuracy: 0.9538 - val_loss: 0.1601
# Epoch 189/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9537 - loss: 0.1647 - val_accuracy: 0.9552 - val_loss: 0.1593
# Epoch 190/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9538 - loss: 0.1641 - val_accuracy: 0.9541 - val_loss: 0.1590
# Epoch 191/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9539 - loss: 0.1634 - val_accuracy: 0.9554 - val_loss: 0.1581
# Epoch 192/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9539 - loss: 0.1627 - val_accuracy: 0.9552 - val_loss: 0.1577
# Epoch 193/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9543 - loss: 0.1620 - val_accuracy: 0.9554 - val_loss: 0.1574
# Epoch 194/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9546 - loss: 0.1613 - val_accuracy: 0.9559 - val_loss: 0.1571
# Epoch 195/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9547 - loss: 0.1606 - val_accuracy: 0.9566 - val_loss: 0.1563
# Epoch 196/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9548 - loss: 0.1600 - val_accuracy: 0.9554 - val_loss: 0.1558
# Epoch 197/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9549 - loss: 0.1593 - val_accuracy: 0.9563 - val_loss: 0.1553
# Epoch 198/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9550 - loss: 0.1586 - val_accuracy: 0.9561 - val_loss: 0.1552
# Epoch 199/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9553 - loss: 0.1580 - val_accuracy: 0.9559 - val_loss: 0.1545
# Epoch 200/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9556 - loss: 0.1572 - val_accuracy: 0.9566 - val_loss: 0.1537
# Epoch 201/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9558 - loss: 0.1566 - val_accuracy: 0.9571 - val_loss: 0.1533
# Epoch 202/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9557 - loss: 0.1561 - val_accuracy: 0.9569 - val_loss: 0.1527
# Epoch 203/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9562 - loss: 0.1553 - val_accuracy: 0.9578 - val_loss: 0.1523
# Epoch 204/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9563 - loss: 0.1547 - val_accuracy: 0.9571 - val_loss: 0.1522
# Epoch 205/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9564 - loss: 0.1541 - val_accuracy: 0.9576 - val_loss: 0.1513
# Epoch 206/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9562 - loss: 0.1534 - val_accuracy: 0.9576 - val_loss: 0.1512
# Epoch 207/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9567 - loss: 0.1528 - val_accuracy: 0.9578 - val_loss: 0.1505
# Epoch 208/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9567 - loss: 0.1522 - val_accuracy: 0.9579 - val_loss: 0.1498
# Epoch 209/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9570 - loss: 0.1516 - val_accuracy: 0.9574 - val_loss: 0.1494
# Epoch 210/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9572 - loss: 0.1510 - val_accuracy: 0.9578 - val_loss: 0.1490
# Epoch 211/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9577 - loss: 0.1504 - val_accuracy: 0.9576 - val_loss: 0.1489
# Epoch 212/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9575 - loss: 0.1497 - val_accuracy: 0.9589 - val_loss: 0.1480
# Epoch 213/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9577 - loss: 0.1492 - val_accuracy: 0.9576 - val_loss: 0.1480
# Epoch 214/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9578 - loss: 0.1486 - val_accuracy: 0.9590 - val_loss: 0.1477
# Epoch 215/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9579 - loss: 0.1480 - val_accuracy: 0.9583 - val_loss: 0.1471
# Epoch 216/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9584 - loss: 0.1474 - val_accuracy: 0.9590 - val_loss: 0.1468
# Epoch 217/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9583 - loss: 0.1469 - val_accuracy: 0.9586 - val_loss: 0.1463
# Epoch 218/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9582 - loss: 0.1462 - val_accuracy: 0.9583 - val_loss: 0.1458
# Epoch 219/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9586 - loss: 0.1457 - val_accuracy: 0.9588 - val_loss: 0.1458
# Epoch 220/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9585 - loss: 0.1451 - val_accuracy: 0.9588 - val_loss: 0.1452
# Epoch 221/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9586 - loss: 0.1445 - val_accuracy: 0.9594 - val_loss: 0.1446
# Epoch 222/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9590 - loss: 0.1440 - val_accuracy: 0.9591 - val_loss: 0.1444
# Epoch 223/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9590 - loss: 0.1434 - val_accuracy: 0.9593 - val_loss: 0.1440
# Epoch 224/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9593 - loss: 0.1429 - val_accuracy: 0.9589 - val_loss: 0.1435
# Epoch 225/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9594 - loss: 0.1423 - val_accuracy: 0.9593 - val_loss: 0.1436
# Epoch 226/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9596 - loss: 0.1418 - val_accuracy: 0.9591 - val_loss: 0.1426
# Epoch 227/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9597 - loss: 0.1412 - val_accuracy: 0.9593 - val_loss: 0.1428
# Epoch 228/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9597 - loss: 0.1407 - val_accuracy: 0.9594 - val_loss: 0.1420
# Epoch 229/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.9601 - loss: 0.1401 - val_accuracy: 0.9588 - val_loss: 0.1417
# Epoch 230/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9601 - loss: 0.1396 - val_accuracy: 0.9600 - val_loss: 0.1417
# Epoch 231/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9603 - loss: 0.1390 - val_accuracy: 0.9597 - val_loss: 0.1410
# Epoch 232/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9605 - loss: 0.1384 - val_accuracy: 0.9588 - val_loss: 0.1416
# Epoch 233/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9604 - loss: 0.1380 - val_accuracy: 0.9598 - val_loss: 0.1405
# Epoch 234/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9606 - loss: 0.1375 - val_accuracy: 0.9600 - val_loss: 0.1400
# Epoch 235/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9607 - loss: 0.1369 - val_accuracy: 0.9608 - val_loss: 0.1399
# Epoch 236/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9610 - loss: 0.1364 - val_accuracy: 0.9603 - val_loss: 0.1396
# Epoch 237/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9611 - loss: 0.1359 - val_accuracy: 0.9599 - val_loss: 0.1392
# Epoch 238/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9614 - loss: 0.1354 - val_accuracy: 0.9612 - val_loss: 0.1384
# Epoch 239/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9613 - loss: 0.1349 - val_accuracy: 0.9604 - val_loss: 0.1382
# Epoch 240/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9615 - loss: 0.1344 - val_accuracy: 0.9612 - val_loss: 0.1377
# Epoch 241/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9617 - loss: 0.1339 - val_accuracy: 0.9606 - val_loss: 0.1376
# Epoch 242/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9620 - loss: 0.1334 - val_accuracy: 0.9609 - val_loss: 0.1379
# Epoch 243/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9619 - loss: 0.1330 - val_accuracy: 0.9611 - val_loss: 0.1371
# Epoch 244/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9622 - loss: 0.1324 - val_accuracy: 0.9609 - val_loss: 0.1367
# Epoch 245/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9620 - loss: 0.1320 - val_accuracy: 0.9610 - val_loss: 0.1364
# Epoch 246/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9626 - loss: 0.1315 - val_accuracy: 0.9613 - val_loss: 0.1361
# Epoch 247/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9625 - loss: 0.1310 - val_accuracy: 0.9610 - val_loss: 0.1359
# Epoch 248/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9628 - loss: 0.1305 - val_accuracy: 0.9611 - val_loss: 0.1360
# Epoch 249/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9627 - loss: 0.1301 - val_accuracy: 0.9613 - val_loss: 0.1352
# Epoch 250/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9631 - loss: 0.1296 - val_accuracy: 0.9616 - val_loss: 0.1353
# Epoch 251/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9631 - loss: 0.1291 - val_accuracy: 0.9621 - val_loss: 0.1345
# Epoch 252/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9635 - loss: 0.1286 - val_accuracy: 0.9622 - val_loss: 0.1342
# Epoch 253/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9634 - loss: 0.1282 - val_accuracy: 0.9617 - val_loss: 0.1347
# Epoch 254/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9636 - loss: 0.1278 - val_accuracy: 0.9620 - val_loss: 0.1342
# Epoch 255/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9637 - loss: 0.1273 - val_accuracy: 0.9623 - val_loss: 0.1339
# Epoch 256/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9641 - loss: 0.1268 - val_accuracy: 0.9622 - val_loss: 0.1334
# Epoch 257/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9639 - loss: 0.1264 - val_accuracy: 0.9624 - val_loss: 0.1332
# Epoch 258/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9638 - loss: 0.1259 - val_accuracy: 0.9624 - val_loss: 0.1325
# Epoch 259/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9639 - loss: 0.1255 - val_accuracy: 0.9629 - val_loss: 0.1322
# Epoch 260/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9645 - loss: 0.1250 - val_accuracy: 0.9627 - val_loss: 0.1323
# Epoch 261/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9641 - loss: 0.1246 - val_accuracy: 0.9627 - val_loss: 0.1325
# Epoch 262/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9645 - loss: 0.1242 - val_accuracy: 0.9630 - val_loss: 0.1318
# Epoch 263/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9646 - loss: 0.1237 - val_accuracy: 0.9632 - val_loss: 0.1313
# Epoch 264/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9647 - loss: 0.1233 - val_accuracy: 0.9629 - val_loss: 0.1308
# Epoch 265/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9651 - loss: 0.1228 - val_accuracy: 0.9634 - val_loss: 0.1311
# Epoch 266/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9650 - loss: 0.1224 - val_accuracy: 0.9637 - val_loss: 0.1310
# Epoch 267/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9653 - loss: 0.1220 - val_accuracy: 0.9634 - val_loss: 0.1308
# Epoch 268/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9654 - loss: 0.1216 - val_accuracy: 0.9631 - val_loss: 0.1301
# Epoch 269/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9653 - loss: 0.1212 - val_accuracy: 0.9636 - val_loss: 0.1295
# Epoch 270/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9654 - loss: 0.1208 - val_accuracy: 0.9642 - val_loss: 0.1298
# Epoch 271/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9657 - loss: 0.1203 - val_accuracy: 0.9638 - val_loss: 0.1294
# Epoch 272/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9659 - loss: 0.1198 - val_accuracy: 0.9637 - val_loss: 0.1290
# Epoch 273/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9660 - loss: 0.1196 - val_accuracy: 0.9643 - val_loss: 0.1290
# Epoch 274/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9663 - loss: 0.1192 - val_accuracy: 0.9640 - val_loss: 0.1288
# Epoch 275/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9663 - loss: 0.1188 - val_accuracy: 0.9646 - val_loss: 0.1286
# Epoch 276/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9659 - loss: 0.1183 - val_accuracy: 0.9641 - val_loss: 0.1285
# Epoch 277/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9664 - loss: 0.1179 - val_accuracy: 0.9646 - val_loss: 0.1282
# Epoch 278/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9666 - loss: 0.1175 - val_accuracy: 0.9641 - val_loss: 0.1278
# Epoch 279/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9668 - loss: 0.1171 - val_accuracy: 0.9647 - val_loss: 0.1279
# Epoch 280/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9668 - loss: 0.1168 - val_accuracy: 0.9641 - val_loss: 0.1272
# Epoch 281/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9671 - loss: 0.1164 - val_accuracy: 0.9643 - val_loss: 0.1273
# Epoch 282/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9670 - loss: 0.1159 - val_accuracy: 0.9648 - val_loss: 0.1268
# Epoch 283/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9675 - loss: 0.1156 - val_accuracy: 0.9647 - val_loss: 0.1269
# Epoch 284/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9674 - loss: 0.1152 - val_accuracy: 0.9649 - val_loss: 0.1267
# Epoch 285/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9675 - loss: 0.1148 - val_accuracy: 0.9643 - val_loss: 0.1266
# Epoch 286/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9678 - loss: 0.1144 - val_accuracy: 0.9648 - val_loss: 0.1263
# Epoch 287/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9679 - loss: 0.1140 - val_accuracy: 0.9650 - val_loss: 0.1256
# Epoch 288/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9680 - loss: 0.1136 - val_accuracy: 0.9651 - val_loss: 0.1256
# Epoch 289/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9684 - loss: 0.1133 - val_accuracy: 0.9647 - val_loss: 0.1254
# Epoch 290/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9682 - loss: 0.1129 - val_accuracy: 0.9651 - val_loss: 0.1251
# Epoch 291/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9683 - loss: 0.1126 - val_accuracy: 0.9648 - val_loss: 0.1253
# Epoch 292/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9683 - loss: 0.1122 - val_accuracy: 0.9657 - val_loss: 0.1245
# Epoch 293/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9688 - loss: 0.1118 - val_accuracy: 0.9651 - val_loss: 0.1245
# Epoch 294/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9687 - loss: 0.1114 - val_accuracy: 0.9657 - val_loss: 0.1250
# Epoch 295/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9688 - loss: 0.1111 - val_accuracy: 0.9653 - val_loss: 0.1246
# Epoch 296/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9690 - loss: 0.1108 - val_accuracy: 0.9653 - val_loss: 0.1243
# Epoch 297/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9690 - loss: 0.1103 - val_accuracy: 0.9654 - val_loss: 0.1242
# Epoch 298/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9692 - loss: 0.1100 - val_accuracy: 0.9652 - val_loss: 0.1239
# Epoch 299/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9694 - loss: 0.1097 - val_accuracy: 0.9652 - val_loss: 0.1234
# Epoch 300/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9695 - loss: 0.1093 - val_accuracy: 0.9654 - val_loss: 0.1235
# Epoch 301/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9692 - loss: 0.1090 - val_accuracy: 0.9656 - val_loss: 0.1230
# Epoch 302/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9696 - loss: 0.1086 - val_accuracy: 0.9661 - val_loss: 0.1228
# Epoch 303/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9699 - loss: 0.1083 - val_accuracy: 0.9659 - val_loss: 0.1229
# Epoch 304/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9700 - loss: 0.1080 - val_accuracy: 0.9659 - val_loss: 0.1230
# Epoch 305/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9699 - loss: 0.1076 - val_accuracy: 0.9660 - val_loss: 0.1223
# Epoch 306/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9701 - loss: 0.1072 - val_accuracy: 0.9661 - val_loss: 0.1225
# Epoch 307/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9702 - loss: 0.1069 - val_accuracy: 0.9664 - val_loss: 0.1224
# Epoch 308/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9703 - loss: 0.1065 - val_accuracy: 0.9656 - val_loss: 0.1222
# Epoch 309/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9704 - loss: 0.1063 - val_accuracy: 0.9659 - val_loss: 0.1218
# Epoch 310/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9704 - loss: 0.1060 - val_accuracy: 0.9662 - val_loss: 0.1213
# Epoch 311/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9705 - loss: 0.1056 - val_accuracy: 0.9662 - val_loss: 0.1211
# Epoch 312/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9705 - loss: 0.1052 - val_accuracy: 0.9657 - val_loss: 0.1216
# Epoch 313/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9709 - loss: 0.1049 - val_accuracy: 0.9658 - val_loss: 0.1217
# Epoch 314/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9708 - loss: 0.1046 - val_accuracy: 0.9661 - val_loss: 0.1211
# Epoch 315/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9709 - loss: 0.1043 - val_accuracy: 0.9662 - val_loss: 0.1206
# Epoch 316/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9714 - loss: 0.1039 - val_accuracy: 0.9667 - val_loss: 0.1215
# Epoch 317/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9711 - loss: 0.1036 - val_accuracy: 0.9660 - val_loss: 0.1210
# Epoch 318/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9712 - loss: 0.1033 - val_accuracy: 0.9663 - val_loss: 0.1203
# Epoch 319/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9715 - loss: 0.1030 - val_accuracy: 0.9667 - val_loss: 0.1203
# Epoch 320/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9715 - loss: 0.1027 - val_accuracy: 0.9667 - val_loss: 0.1202
# Epoch 321/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9717 - loss: 0.1023 - val_accuracy: 0.9668 - val_loss: 0.1196
# Epoch 322/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9719 - loss: 0.1021 - val_accuracy: 0.9669 - val_loss: 0.1195
# Epoch 323/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9719 - loss: 0.1017 - val_accuracy: 0.9669 - val_loss: 0.1195
# Epoch 324/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9720 - loss: 0.1014 - val_accuracy: 0.9664 - val_loss: 0.1196
# Epoch 325/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9718 - loss: 0.1011 - val_accuracy: 0.9666 - val_loss: 0.1193
# Epoch 326/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9723 - loss: 0.1008 - val_accuracy: 0.9666 - val_loss: 0.1194
# Epoch 327/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9724 - loss: 0.1005 - val_accuracy: 0.9669 - val_loss: 0.1185
# Epoch 328/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9724 - loss: 0.1002 - val_accuracy: 0.9667 - val_loss: 0.1191
# Epoch 329/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9722 - loss: 0.0999 - val_accuracy: 0.9672 - val_loss: 0.1183
# Epoch 330/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9725 - loss: 0.0996 - val_accuracy: 0.9666 - val_loss: 0.1185
# Epoch 331/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9724 - loss: 0.0993 - val_accuracy: 0.9671 - val_loss: 0.1181
# Epoch 332/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9725 - loss: 0.0990 - val_accuracy: 0.9667 - val_loss: 0.1179
# Epoch 333/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9729 - loss: 0.0987 - val_accuracy: 0.9666 - val_loss: 0.1185
# Epoch 334/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9728 - loss: 0.0984 - val_accuracy: 0.9673 - val_loss: 0.1173
# Epoch 335/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9729 - loss: 0.0981 - val_accuracy: 0.9676 - val_loss: 0.1178
# Epoch 336/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9731 - loss: 0.0978 - val_accuracy: 0.9664 - val_loss: 0.1179
# Epoch 337/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9728 - loss: 0.0975 - val_accuracy: 0.9673 - val_loss: 0.1173
# Epoch 338/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9731 - loss: 0.0972 - val_accuracy: 0.9670 - val_loss: 0.1172
# Epoch 339/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9732 - loss: 0.0970 - val_accuracy: 0.9670 - val_loss: 0.1172
# Epoch 340/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9733 - loss: 0.0966 - val_accuracy: 0.9670 - val_loss: 0.1172
# Epoch 341/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9734 - loss: 0.0964 - val_accuracy: 0.9668 - val_loss: 0.1168
# Epoch 342/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9738 - loss: 0.0961 - val_accuracy: 0.9670 - val_loss: 0.1169
# Epoch 343/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9738 - loss: 0.0958 - val_accuracy: 0.9667 - val_loss: 0.1167
# Epoch 344/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9737 - loss: 0.0955 - val_accuracy: 0.9672 - val_loss: 0.1165
# Epoch 345/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9741 - loss: 0.0952 - val_accuracy: 0.9677 - val_loss: 0.1165
# Epoch 346/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9739 - loss: 0.0950 - val_accuracy: 0.9671 - val_loss: 0.1163
# Epoch 347/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9740 - loss: 0.0946 - val_accuracy: 0.9670 - val_loss: 0.1164
# Epoch 348/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9739 - loss: 0.0944 - val_accuracy: 0.9673 - val_loss: 0.1160
# Epoch 349/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9743 - loss: 0.0941 - val_accuracy: 0.9673 - val_loss: 0.1162
# Epoch 350/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9741 - loss: 0.0939 - val_accuracy: 0.9674 - val_loss: 0.1155
# Epoch 351/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9745 - loss: 0.0936 - val_accuracy: 0.9676 - val_loss: 0.1163
# Epoch 352/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9744 - loss: 0.0934 - val_accuracy: 0.9673 - val_loss: 0.1156
# Epoch 353/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9746 - loss: 0.0930 - val_accuracy: 0.9670 - val_loss: 0.1154
# Epoch 354/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9746 - loss: 0.0928 - val_accuracy: 0.9671 - val_loss: 0.1151
# Epoch 355/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9749 - loss: 0.0925 - val_accuracy: 0.9683 - val_loss: 0.1155
# Epoch 356/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9746 - loss: 0.0922 - val_accuracy: 0.9681 - val_loss: 0.1157
# Epoch 357/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9747 - loss: 0.0920 - val_accuracy: 0.9673 - val_loss: 0.1151
# Epoch 358/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9750 - loss: 0.0917 - val_accuracy: 0.9678 - val_loss: 0.1153

# %% [markdown]
# #Parameters and Setup

# %%
batch_size = 128
epochs = 2000

# %% [markdown]
# #Callbacks

# %%
callbacks = [
keras.callbacks.ModelCheckpoint(filepath="model_at_epoch_{epoch}.keras"),
keras.callbacks.EarlyStopping(monitor="val_loss", patience=4),
]

# %% [markdown]
# #Training the Model

# %%
history = model.fit(
x_train,
y_train,
batch_size=batch_size,
epochs=epochs,
validation_split=0.15,
callbacks=callbacks,
)
# Out:
# Epoch 1/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9751 - loss: 0.0914 - val_accuracy: 0.9672 - val_loss: 0.1155
# Epoch 2/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9750 - loss: 0.0912 - val_accuracy: 0.9683 - val_loss: 0.1145
# Epoch 3/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9751 - loss: 0.0910 - val_accuracy: 0.9678 - val_loss: 0.1142
# Epoch 4/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9754 - loss: 0.0907 - val_accuracy: 0.9678 - val_loss: 0.1143
# Epoch 5/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9754 - loss: 0.0904 - val_accuracy: 0.9680 - val_loss: 0.1141
# Epoch 6/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9756 - loss: 0.0902 - val_accuracy: 0.9682 - val_loss: 0.1142
# Epoch 7/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9756 - loss: 0.0899 - val_accuracy: 0.9683 - val_loss: 0.1143
# Epoch 8/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9756 - loss: 0.0897 - val_accuracy: 0.9680 - val_loss: 0.1137
# Epoch 9/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9757 - loss: 0.0894 - val_accuracy: 0.9682 - val_loss: 0.1134
# Epoch 10/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9755 - loss: 0.0891 - val_accuracy: 0.9683 - val_loss: 0.1147
# Epoch 11/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9758 - loss: 0.0889 - val_accuracy: 0.9682 - val_loss: 0.1140
# Epoch 12/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9759 - loss: 0.0886 - val_accuracy: 0.9683 - val_loss: 0.1140
# Epoch 13/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9759 - loss: 0.0884 - val_accuracy: 0.9678 - val_loss: 0.1133
# Epoch 14/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9761 - loss: 0.0882 - val_accuracy: 0.9684 - val_loss: 0.1131
# Epoch 15/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9758 - loss: 0.0879 - val_accuracy: 0.9676 - val_loss: 0.1130
# Epoch 16/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9762 - loss: 0.0877 - val_accuracy: 0.9683 - val_loss: 0.1127
# Epoch 17/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9761 - loss: 0.0874 - val_accuracy: 0.9683 - val_loss: 0.1130
# Epoch 18/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9761 - loss: 0.0872 - val_accuracy: 0.9684 - val_loss: 0.1135
# Epoch 19/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9762 - loss: 0.0869 - val_accuracy: 0.9682 - val_loss: 0.1135
# Epoch 20/2000
# 399/399 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.9762 - loss: 0.0867 - val_accuracy: 0.9680 - val_loss: 0.1129

# %% [markdown]
# #Sample Code for visualizing Model's Training Progress.

# %%
import matplotlib.pyplot as plt
# Assuming 'history' is the object returned by model.fit()
# Extracting training and validation loss
train_loss = history.history['loss']
val_loss = history.history['val_loss']
# Extracting training and validation accuracy (if metrics were specified)
train_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
# Plotting training and validation loss
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss', color='blue')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
# Plotting training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_acc) + 1), train_acc, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_acc) + 1), val_acc, label='Validation Accuracy', color='orange')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# #Syntax for model.evaluate()

# %%
model.evaluate(x=x_test, y=y_test, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9665 - loss: 0.1154
# [0.11535099893808365, 0.9664999842643738]

# %% [markdown]
# #Example code for Evaluation.

# %%
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 313/313 - 1s - 3ms/step - accuracy: 0.9665 - loss: 0.1154
# Test accuracy: 0.9665

# %% [markdown]
# #model.predict()

# %%
predictions = model.predict(x_test)
# Convert predictions from probabilities to digit labels
predicted_labels = np.argmax(predictions, axis=1)
# Check the first prediction
print(f"Predicted label for first image: {predicted_labels[0]}")
print(f"True label for first image: {np.argmax(y_test[0])}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Predicted label for first image: 7
# True label for first image: 7

# %% [markdown]
# #Saving the Model

# %%
model.save('mnist_fully_connected_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# #Loading the Model

# %%
loaded_model = tf.keras.models.load_model('mnist_fully_connected_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
